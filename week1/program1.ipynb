# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaVardhanReddy555/python-programs/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("harsha")
# Out:
# harsha

# %%
#arthemetic operations
x=int(input("enter int value:"))
y=int(input("enter another:"))
print("sum of x and y is",x+y)
print("substraction of x and y are",x-y)
print("muliplicaiton is ",x*y)
print("division of x and y is ",x/y)
print("power of x and y is",x**y)
print("division with of type casting is",x//y)
print("reminder of division is ",x%y)
# Out:
# enter int value:5
# enter another:3
# sum of x and y is 8
# substraction of x and y are 2
# muliplicaiton is  15
# division of x and y is  1.6666666666666667
# power of x and y is 125
# division with of type casting is 1
# reminder of division is  2

# %%
#comparision operations
print(x==y)
print(x>=y)
print(x<=y)
print(x<y)
print(x>y)
print(x!=y)
# Out:
# False
# True
# False
# False
# True
# True

# %%
#assignment operator
a=5
a+=1
print(a)
a-=1
print(a)
a*=2
print(a)
# Out:
# 6
# 5
# 10
